# %% [markdown]
# K mean

# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler

# %%
live = pd.read_csv("F:\Live.csv")

# %%
live
# Out:
#                               status_id status_type  status_published  \
# 0      246675545449582_1649696485147474       video    4/22/2018 6:00
# 1      246675545449582_1649426988507757       photo   4/21/2018 22:45
# 2      246675545449582_1648730588577397       video    4/21/2018 6:17
# 3      246675545449582_1648576705259452       photo    4/21/2018 2:29
# 4      246675545449582_1645700502213739       photo    4/18/2018 3:22
# ...                                 ...         ...               ...
# 7045  1050855161656896_1061863470556065       photo    9/24/2016 2:58
# 7046  1050855161656896_1061334757275603       photo   9/23/2016 11:19
# 7047  1050855161656896_1060126464063099       photo   9/21/2016 23:03
# 7048  1050855161656896_1058663487542730       photo    9/20/2016 0:43
# 7049  1050855161656896_1050858841656528       photo  09-10-2016 10:30
#
#       num_reactions  num_comments  num_shares  num_likes  num_loves  num_wows  \
# ...

# %%
live.isna().value_counts()
# Out:
# status_id  status_type  status_published  num_reactions  num_comments  num_shares  num_likes  num_loves  num_wows  num_hahas  num_sads  num_angrys  Column1  Column2  Column3  Column4
# False      False        False             False          False         False       False      False      False     False      False     False       True     True     True     True       7050
# dtype: int64

# %%
live = live.iloc[:,1:12]

# %%
live
# Out:
#      status_type  status_published  num_reactions  num_comments  num_shares  \
# 0          video    4/22/2018 6:00            529           512         262
# 1          photo   4/21/2018 22:45            150             0           0
# 2          video    4/21/2018 6:17            227           236          57
# 3          photo    4/21/2018 2:29            111             0           0
# 4          photo    4/18/2018 3:22            213             0           0
# ...          ...               ...            ...           ...         ...
# 7045       photo    9/24/2016 2:58             89             0           0
# 7046       photo   9/23/2016 11:19             16             0           0
# 7047       photo   9/21/2016 23:03              2             0           0
# 7048       photo    9/20/2016 0:43            351            12          22
# 7049       photo  09-10-2016 10:30             17             0           0
#
# ...

# %%
live.isna().value_counts()
# Out:
# status_type  status_published  num_reactions  num_comments  num_shares  num_likes  num_loves  num_wows  num_hahas  num_sads  num_angrys
# False        False             False          False         False       False      False      False     False      False     False         7050
# dtype: int64

# %%
import dtale

# %%
dtale.show(live)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://DESKTOP-QND3GRH:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
live = live.drop(['status_published'] ,axis = 1)

# %%
live
# Out:
#      status_type  num_reactions  num_comments  num_shares  num_likes  \
# 0          video            529           512         262        432
# 1          photo            150             0           0        150
# 2          video            227           236          57        204
# 3          photo            111             0           0        111
# 4          photo            213             0           0        204
# ...          ...            ...           ...         ...        ...
# 7045       photo             89             0           0         89
# 7046       photo             16             0           0         14
# 7047       photo              2             0           0          1
# 7048       photo            351            12          22        349
# 7049       photo             17             0           0         17
#
#       num_loves  num_wows  num_hahas  num_sads  num_angrys
# 0            92         3          1         1           0
# ...

# %%
import matplotlib.pyplot as plt

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb = LabelEncoder()

# %%
live['status_type'] = lb.fit_transform(live['status_type'])

# %%
live
# Out:
#       status_type  num_reactions  num_comments  num_shares  num_likes  \
# 0               3            529           512         262        432
# 1               1            150             0           0        150
# 2               3            227           236          57        204
# 3               1            111             0           0        111
# 4               1            213             0           0        204
# ...           ...            ...           ...         ...        ...
# 7045            1             89             0           0         89
# 7046            1             16             0           0         14
# 7047            1              2             0           0          1
# 7048            1            351            12          22        349
# 7049            1             17             0           0         17
#
#       num_loves  num_wows  num_hahas  num_sads  num_angrys
# 0            92         3          1         1           0
# ...

# %%
dis = []
K = range(1,10)
for k in K:
    kmeanModel = KMeans(n_clusters=k)
    kmeanModel.fit(live)
    dis.append(kmeanModel.inertia_)
dis
# Out:
# [8645704000.446217,
#  4986407097.981185,
#  2735270445.9526844,
#  2000985072.7696624,
#  1469931103.359638,
#  1187008753.0729067,
#  923460765.7787106,
#  749972865.3891178,
#  621407625.2493079]

# %%
plt.figure(figsize=(8,8))
plt.plot(K, dis, 'bx-')
plt.xlabel('k')
plt.ylabel('Dis')
plt.title('The Elbow Method showing the optimal k')
plt.show()

# %%
#pip install pyqt5

# %%
kmeanModel = KMeans(n_clusters = 7)
kmeanModel.fit(live)
# Out:
# KMeans(n_clusters=7)

# %%
kmeanModel.labels_
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
live['cluster'] = kmeanModel.labels_

# %%
live
# Out:
#       status_type  num_reactions  num_comments  num_shares  num_likes  \
# 0               3            529           512         262        432
# 1               1            150             0           0        150
# 2               3            227           236          57        204
# 3               1            111             0           0        111
# 4               1            213             0           0        204
# ...           ...            ...           ...         ...        ...
# 7045            1             89             0           0         89
# 7046            1             16             0           0         14
# 7047            1              2             0           0          1
# 7048            1            351            12          22        349
# 7049            1             17             0           0         17
#
#       num_loves  num_wows  num_hahas  num_sads  num_angrys  cluster
# ...
